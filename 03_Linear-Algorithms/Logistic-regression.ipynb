# %% [markdown]
# # Logistic regression
#
# Logistic regression is named for the function used at the core of the method, the logistic function.
# Logistic regression uses an equation as the representation, very much like linear regression.
#
#
# Equation is written as:
#
# yhat = 1/(1+e^z)
# where z = b0+b1*x1)
#
# yhat is a real value between 0 and 1 that needs to be rounded to an integer value and mapped to a predicted class value.

# %% [markdown]
# # Stochastic gradient descent
#
# We use stochastic gradient descent here as well but the coefficient formula is different
#
# b = b + (learning rate) * (y - yhat) * yhat * (1 - yhat) * x

# %% [markdown]
# # Steps involved in this notebook
#
# There are 3 parts here:
# 1. Making predictions
# 2. Estimating coefficients
# 3. Case study on [Pima Indians Diabetes](https://www.kaggle.com/datasets/uciml/pima-indians-diabetes-database)

# %% [markdown]
# # 1. Making predictions

# %%
from math import exp
def predict(row, coefficients):
    yhat = coefficients[0]
    for i in range(len(row) - 1):
        yhat += coefficients[i+1] * row[i]
    return 1.0 / (1.0 + exp(-yhat))

# %%
# testing the predict function

dataset = [[2.7810836,2.550537003,0],
[1.465489372,2.362125076,0],
[3.396561688,4.400293529,0],
[1.38807019,1.850220317,0],
[3.06407232,3.005305973,0],
[7.627531214,2.759262235,1],
[5.332441248,2.088626775,1],
[6.922596716,1.77106367,1],
[8.675418651,-0.242068655,1],
[7.673756466,3.508563011,1]]

coef = [-0.406605464, 0.852573316, -1.104746259]

for row in dataset:
    yhat = predict(row, coef)
    print(f"Expected: {round(row[-1], 3)} Predicted: {round(yhat, 3)}  [{round(yhat)}]")
# Out:
# Expected: 0 Predicted: 0.299  [0]
# Expected: 0 Predicted: 0.146  [0]
# Expected: 0 Predicted: 0.085  [0]
# Expected: 0 Predicted: 0.22  [0]
# Expected: 0 Predicted: 0.247  [0]
# Expected: 1 Predicted: 0.955  [1]
# Expected: 1 Predicted: 0.862  [1]
# Expected: 1 Predicted: 0.972  [1]
# Expected: 1 Predicted: 0.999  [1]
# Expected: 1 Predicted: 0.905  [1]

# %% [markdown]
# # Estimating coefficients

# %% [markdown]
# using stochastic gradient descent to figure out the coefficients

# %%
def coefficients_sgd(train, l_rate, n_epoch):
    coef = [0.0 for i in range(len(train[0]))]
    for epoch in range(n_epoch):
        sum_error = 0
        for row in train:
            yhat = predict(row, coef)
            error = row[-1] - yhat
            sum_error += (error ** 2)
        
            coef[0] = coef[0] + l_rate * error * yhat * (1.0 - yhat)
            
            for i in range(len(row) - 1):
                coef[i+1] = coef[i+1] + l_rate * error * yhat * (1.0 - yhat) * row[i]
        print(f"Epoch: {epoch}, lrate: {l_rate}, error: {round(sum_error, 3)}")
    return coef

# %% [markdown]
# Example on dummy data

# %%
dataset = [[2.7810836,2.550537003,0],
[1.465489372,2.362125076,0],
[3.396561688,4.400293529,0],
[1.38807019,1.850220317,0],
[3.06407232,3.005305973,0],
[7.627531214,2.759262235,1],
[5.332441248,2.088626775,1],
[6.922596716,1.77106367,1],
[8.675418651,-0.242068655,1],
[7.673756466,3.508563011,1]]
l_rate = 0.3
n_epoch = 50
coef = coefficients_sgd(dataset, l_rate, n_epoch)
print(coef)
# Out:
# Epoch: 0, lrate: 0.3, error: 2.217
# Epoch: 1, lrate: 0.3, error: 1.613
# Epoch: 2, lrate: 0.3, error: 1.113
# Epoch: 3, lrate: 0.3, error: 0.827
# Epoch: 4, lrate: 0.3, error: 0.623
# Epoch: 5, lrate: 0.3, error: 0.494
# Epoch: 6, lrate: 0.3, error: 0.412
# Epoch: 7, lrate: 0.3, error: 0.354
# Epoch: 8, lrate: 0.3, error: 0.31
# Epoch: 9, lrate: 0.3, error: 0.276
# Epoch: 10, lrate: 0.3, error: 0.248
# Epoch: 11, lrate: 0.3, error: 0.224
# Epoch: 12, lrate: 0.3, error: 0.205
# Epoch: 13, lrate: 0.3, error: 0.189
# Epoch: 14, lrate: 0.3, error: 0.174
# Epoch: 15, lrate: 0.3, error: 0.162
# Epoch: 16, lrate: 0.3, error: 0.151
# Epoch: 17, lrate: 0.3, error: 0.142
# Epoch: 18, lrate: 0.3, error: 0.134
# Epoch: 19, lrate: 0.3, error: 0.126
# Epoch: 20, lrate: 0.3, error: 0.119
# Epoch: 21, lrate: 0.3, error: 0.113
# Epoch: 22, lrate: 0.3, error: 0.108
# Epoch: 23, lrate: 0.3, error: 0.103
# Epoch: 24, lrate: 0.3, error: 0.098
# Epoch: 25, lrate: 0.3, error: 0.094
# Epoch: 26, lrate: 0.3, error: 0.09
# Epoch: 27, lrate: 0.3, error: 0.087
# Epoch: 28, lrate: 0.3, error: 0.084
# Epoch: 29, lrate: 0.3, error: 0.08
# Epoch: 30, lrate: 0.3, error: 0.078
# Epoch: 31, lrate: 0.3, error: 0.075
# Epoch: 32, lrate: 0.3, error: 0.073
# Epoch: 33, lrate: 0.3, error: 0.07
# Epoch: 34, lrate: 0.3, error: 0.068
# Epoch: 35, lrate: 0.3, error: 0.066
# Epoch: 36, lrate: 0.3, error: 0.064
# Epoch: 37, lrate: 0.3, error: 0.062
# Epoch: 38, lrate: 0.3, error: 0.06
# Epoch: 39, lrate: 0.3, error: 0.059
# Epoch: 40, lrate: 0.3, error: 0.057
# Epoch: 41, lrate: 0.3, error: 0.056
# Epoch: 42, lrate: 0.3, error: 0.054
# Epoch: 43, lrate: 0.3, error: 0.053
# Epoch: 44, lrate: 0.3, error: 0.052
# Epoch: 45, lrate: 0.3, error: 0.051
# Epoch: 46, lrate: 0.3, error: 0.05
# Epoch: 47, lrate: 0.3, error: 0.048
# Epoch: 48, lrate: 0.3, error: 0.047
# Epoch: 49, lrate: 0.3, error: 0.046
# [-0.7282458823836234, 1.3156310025113396, -1.8978207115152121]

# %% [markdown]
# # Case study

# %%
# %run helper-functions.ipynb

# %%
# Logistic regression algorithm with SGD
def logistic_regression(train, test, l_rate, n_poch):
    predictions = list()
    coef = coefficients_sgd(train, l_rate, n_epoch)
    
    for row in test:
        yhat = predict(row, coef)
        yhat = round(yhat)
        predictions.append(yhat)
    return(predictions)

# %%
# Testing the algorithm on dataset

seed(1)
filename = 'diabetes.csv'
dataset = load_csv(filename)

for i in range(len(dataset[0])):
    str_column_to_float(dataset, i)

#normalize
minmax = dataset_minmax(dataset)
normalize_dataset(dataset, minmax)

# %%
# Evaluate algorithm

n_folds = 5
l_rate = 0.1
n_epoch = 100
scores = evaluate_algorithm(dataset, logistic_regression, n_folds, l_rate, n_epoch)
print("ScoresL %s" % scores)
print('Mean Accuracy: %3f%%' % (sum(scores) / float(len(scores))))
# Out:
# Epoch: 0, lrate: 0.1, error: 139.813
# Epoch: 1, lrate: 0.1, error: 133.309
# Epoch: 2, lrate: 0.1, error: 128.382
# Epoch: 3, lrate: 0.1, error: 124.424
# Epoch: 4, lrate: 0.1, error: 121.213
# Epoch: 5, lrate: 0.1, error: 118.571
# Epoch: 6, lrate: 0.1, error: 116.362
# Epoch: 7, lrate: 0.1, error: 114.487
# Epoch: 8, lrate: 0.1, error: 112.875
# Epoch: 9, lrate: 0.1, error: 111.473
# Epoch: 10, lrate: 0.1, error: 110.24
# Epoch: 11, lrate: 0.1, error: 109.148
# Epoch: 12, lrate: 0.1, error: 108.172
# Epoch: 13, lrate: 0.1, error: 107.294
# Epoch: 14, lrate: 0.1, error: 106.501
# Epoch: 15, lrate: 0.1, error: 105.78
# Epoch: 16, lrate: 0.1, error: 105.122
# Epoch: 17, lrate: 0.1, error: 104.518
# Epoch: 18, lrate: 0.1, error: 103.963
# Epoch: 19, lrate: 0.1, error: 103.45
# Epoch: 20, lrate: 0.1, error: 102.975
# Epoch: 21, lrate: 0.1, error: 102.533
# Epoch: 22, lrate: 0.1, error: 102.122
# Epoch: 23, lrate: 0.1, error: 101.739
# Epoch: 24, lrate: 0.1, error: 101.38
# Epoch: 25, lrate: 0.1, error: 101.044
# Epoch: 26, lrate: 0.1, error: 100.728
# Epoch: 27, lrate: 0.1, error: 100.431
# Epoch: 28, lrate: 0.1, error: 100.152
# Epoch: 29, lrate: 0.1, error: 99.888
# Epoch: 30, lrate: 0.1, error: 99.638
# Epoch: 31, lrate: 0.1, error: 99.402
# Epoch: 32, lrate: 0.1, error: 99.179
# Epoch: 33, lrate: 0.1, error: 98.967
# Epoch: 34, lrate: 0.1, error: 98.765
# Epoch: 35, lrate: 0.1, error: 98.574
# Epoch: 36, lrate: 0.1, error: 98.392
# Epoch: 37, lrate: 0.1, error: 98.218
# Epoch: 38, lrate: 0.1, error: 98.053
# Epoch: 39, lrate: 0.1, error: 97.895
# Epoch: 40, lrate: 0.1, error: 97.745
# Epoch: 41, lrate: 0.1, error: 97.601
# Epoch: 42, lrate: 0.1, error: 97.463
# Epoch: 43, lrate: 0.1, error: 97.331
# Epoch: 44, lrate: 0.1, error: 97.205
# Epoch: 45, lrate: 0.1, error: 97.085
# Epoch: 46, lrate: 0.1, error: 96.969
# Epoch: 47, lrate: 0.1, error: 96.858
# Epoch: 48, lrate: 0.1, error: 96.751
# Epoch: 49, lrate: 0.1, error: 96.649
# Epoch: 50, lrate: 0.1, error: 96.55
# Epoch: 51, lrate: 0.1, error: 96.456
# Epoch: 52, lrate: 0.1, error: 96.365
# Epoch: 53, lrate: 0.1, error: 96.277
# Epoch: 54, lrate: 0.1, error: 96.193
# Epoch: 55, lrate: 0.1, error: 96.112
# Epoch: 56, lrate: 0.1, error: 96.033
# Epoch: 57, lrate: 0.1, error: 95.958
# Epoch: 58, lrate: 0.1, error: 95.885
# Epoch: 59, lrate: 0.1, error: 95.815
# Epoch: 60, lrate: 0.1, error: 95.747
# Epoch: 61, lrate: 0.1, error: 95.682
# Epoch: 62, lrate: 0.1, error: 95.619
# Epoch: 63, lrate: 0.1, error: 95.557
# Epoch: 64, lrate: 0.1, error: 95.498
# Epoch: 65, lrate: 0.1, error: 95.441
# Epoch: 66, lrate: 0.1, error: 95.386
# Epoch: 67, lrate: 0.1, error: 95.333
# Epoch: 68, lrate: 0.1, error: 95.281
# Epoch: 69, lrate: 0.1, error: 95.231
# Epoch: 70, lrate: 0.1, error: 95.182
# Epoch: 71, lrate: 0.1, error: 95.135
# Epoch: 72, lrate: 0.1, error: 95.09
# Epoch: 73, lrate: 0.1, error: 95.046
# Epoch: 74, lrate: 0.1, error: 95.003
# Epoch: 75, lrate: 0.1, error: 94.961
# Epoch: 76, lrate: 0.1, error: 94.921
# Epoch: 77, lrate: 0.1, error: 94.882
# Epoch: 78, lrate: 0.1, error: 94.844
# Epoch: 79, lrate: 0.1, error: 94.807
# Epoch: 80, lrate: 0.1, error: 94.771
# Epoch: 81, lrate: 0.1, error: 94.737
# Epoch: 82, lrate: 0.1, error: 94.703
# Epoch: 83, lrate: 0.1, error: 94.67
# Epoch: 84, lrate: 0.1, error: 94.638
# Epoch: 85, lrate: 0.1, error: 94.607
# Epoch: 86, lrate: 0.1, error: 94.577
# Epoch: 87, lrate: 0.1, error: 94.548
# Epoch: 88, lrate: 0.1, error: 94.519
# Epoch: 89, lrate: 0.1, error: 94.492
# Epoch: 90, lrate: 0.1, error: 94.465
# Epoch: 91, lrate: 0.1, error: 94.438
# Epoch: 92, lrate: 0.1, error: 94.413
# Epoch: 93, lrate: 0.1, error: 94.388
# Epoch: 94, lrate: 0.1, error: 94.364
# Epoch: 95, lrate: 0.1, error: 94.34
# Epoch: 96, lrate: 0.1, error: 94.317
# Epoch: 97, lrate: 0.1, error: 94.295
# Epoch: 98, lrate: 0.1, error: 94.273
# Epoch: 99, lrate: 0.1, error: 94.251
# Epoch: 0, lrate: 0.1, error: 141.059
# Epoch: 1, lrate: 0.1, error: 134.317
# Epoch: 2, lrate: 0.1, error: 129.498
# Epoch: 3, lrate: 0.1, error: 125.62
# Epoch: 4, lrate: 0.1, error: 122.461
# Epoch: 5, lrate: 0.1, error: 119.847
# Epoch: 6, lrate: 0.1, error: 117.648
# Epoch: 7, lrate: 0.1, error: 115.771
# Epoch: 8, lrate: 0.1, error: 114.149
# Epoch: 9, lrate: 0.1, error: 112.73
# Epoch: 10, lrate: 0.1, error: 111.477
# Epoch: 11, lrate: 0.1, error: 110.363
# Epoch: 12, lrate: 0.1, error: 109.364
# Epoch: 13, lrate: 0.1, error: 108.464
# Epoch: 14, lrate: 0.1, error: 107.649
# Epoch: 15, lrate: 0.1, error: 106.906
# Epoch: 16, lrate: 0.1, error: 106.227
# Epoch: 17, lrate: 0.1, error: 105.603
# Epoch: 18, lrate: 0.1, error: 105.029
# Epoch: 19, lrate: 0.1, error: 104.498
# Epoch: 20, lrate: 0.1, error: 104.007
# Epoch: 21, lrate: 0.1, error: 103.55
# Epoch: 22, lrate: 0.1, error: 103.125
# Epoch: 23, lrate: 0.1, error: 102.728
# Epoch: 24, lrate: 0.1, error: 102.357
# Epoch: 25, lrate: 0.1, error: 102.009
# Epoch: 26, lrate: 0.1, error: 101.683
# Epoch: 27, lrate: 0.1, error: 101.376
# Epoch: 28, lrate: 0.1, error: 101.087
# Epoch: 29, lrate: 0.1, error: 100.815
# Epoch: 30, lrate: 0.1, error: 100.557
# Epoch: 31, lrate: 0.1, error: 100.314
# Epoch: 32, lrate: 0.1, error: 100.083
# Epoch: 33, lrate: 0.1, error: 99.865
# Epoch: 34, lrate: 0.1, error: 99.657
# Epoch: 35, lrate: 0.1, error: 99.46
# Epoch: 36, lrate: 0.1, error: 99.273
# Epoch: 37, lrate: 0.1, error: 99.095
# Epoch: 38, lrate: 0.1, error: 98.925
# Epoch: 39, lrate: 0.1, error: 98.763
# Epoch: 40, lrate: 0.1, error: 98.608
# Epoch: 41, lrate: 0.1, error: 98.46
# Epoch: 42, lrate: 0.1, error: 98.319
# Epoch: 43, lrate: 0.1, error: 98.184
# Epoch: 44, lrate: 0.1, error: 98.055
# Epoch: 45, lrate: 0.1, error: 97.931
# Epoch: 46, lrate: 0.1, error: 97.812
# Epoch: 47, lrate: 0.1, error: 97.698
# Epoch: 48, lrate: 0.1, error: 97.589
# Epoch: 49, lrate: 0.1, error: 97.484
# Epoch: 50, lrate: 0.1, error: 97.383
# Epoch: 51, lrate: 0.1, error: 97.286
# Epoch: 52, lrate: 0.1, error: 97.193
# Epoch: 53, lrate: 0.1, error: 97.103
# Epoch: 54, lrate: 0.1, error: 97.017
# Epoch: 55, lrate: 0.1, error: 96.933
# Epoch: 56, lrate: 0.1, error: 96.853
# Epoch: 57, lrate: 0.1, error: 96.776
# Epoch: 58, lrate: 0.1, error: 96.701
# Epoch: 59, lrate: 0.1, error: 96.629
# Epoch: 60, lrate: 0.1, error: 96.559
# Epoch: 61, lrate: 0.1, error: 96.492
# Epoch: 62, lrate: 0.1, error: 96.427
# Epoch: 63, lrate: 0.1, error: 96.364
# Epoch: 64, lrate: 0.1, error: 96.303
# Epoch: 65, lrate: 0.1, error: 96.245
# Epoch: 66, lrate: 0.1, error: 96.188
# Epoch: 67, lrate: 0.1, error: 96.133
# Epoch: 68, lrate: 0.1, error: 96.079
# Epoch: 69, lrate: 0.1, error: 96.028
# Epoch: 70, lrate: 0.1, error: 95.978
# Epoch: 71, lrate: 0.1, error: 95.929
# Epoch: 72, lrate: 0.1, error: 95.882
# Epoch: 73, lrate: 0.1, error: 95.836
# Epoch: 74, lrate: 0.1, error: 95.792
# Epoch: 75, lrate: 0.1, error: 95.749
# Epoch: 76, lrate: 0.1, error: 95.707
# Epoch: 77, lrate: 0.1, error: 95.667
# Epoch: 78, lrate: 0.1, error: 95.627
# Epoch: 79, lrate: 0.1, error: 95.589
# Epoch: 80, lrate: 0.1, error: 95.552
# Epoch: 81, lrate: 0.1, error: 95.516
# Epoch: 82, lrate: 0.1, error: 95.481
# Epoch: 83, lrate: 0.1, error: 95.447
# Epoch: 84, lrate: 0.1, error: 95.413
# Epoch: 85, lrate: 0.1, error: 95.381
# Epoch: 86, lrate: 0.1, error: 95.349
# Epoch: 87, lrate: 0.1, error: 95.319
# Epoch: 88, lrate: 0.1, error: 95.289
# Epoch: 89, lrate: 0.1, error: 95.26
# Epoch: 90, lrate: 0.1, error: 95.232
# Epoch: 91, lrate: 0.1, error: 95.204
# Epoch: 92, lrate: 0.1, error: 95.177
# Epoch: 93, lrate: 0.1, error: 95.151
# Epoch: 94, lrate: 0.1, error: 95.126
# Epoch: 95, lrate: 0.1, error: 95.101
# Epoch: 96, lrate: 0.1, error: 95.076
# Epoch: 97, lrate: 0.1, error: 95.053
# Epoch: 98, lrate: 0.1, error: 95.03
# Epoch: 99, lrate: 0.1, error: 95.007
# Epoch: 0, lrate: 0.1, error: 140.806
# Epoch: 1, lrate: 0.1, error: 134.124
# Epoch: 2, lrate: 0.1, error: 129.283
# Epoch: 3, lrate: 0.1, error: 125.355
# Epoch: 4, lrate: 0.1, error: 122.142
# Epoch: 5, lrate: 0.1, error: 119.481
# Epoch: 6, lrate: 0.1, error: 117.246
# Epoch: 7, lrate: 0.1, error: 115.345
# Epoch: 8, lrate: 0.1, error: 113.711
# Epoch: 9, lrate: 0.1, error: 112.29
# Epoch: 10, lrate: 0.1, error: 111.044
# Epoch: 11, lrate: 0.1, error: 109.943
# Epoch: 12, lrate: 0.1, error: 108.964
# Epoch: 13, lrate: 0.1, error: 108.087
# Epoch: 14, lrate: 0.1, error: 107.298
# Epoch: 15, lrate: 0.1, error: 106.585
# Epoch: 16, lrate: 0.1, error: 105.937
# Epoch: 17, lrate: 0.1, error: 105.346
# Epoch: 18, lrate: 0.1, error: 104.806
# Epoch: 19, lrate: 0.1, error: 104.31
# Epoch: 20, lrate: 0.1, error: 103.853
# Epoch: 21, lrate: 0.1, error: 103.432
# Epoch: 22, lrate: 0.1, error: 103.041
# Epoch: 23, lrate: 0.1, error: 102.679
# Epoch: 24, lrate: 0.1, error: 102.342
# Epoch: 25, lrate: 0.1, error: 102.028
# Epoch: 26, lrate: 0.1, error: 101.734
# Epoch: 27, lrate: 0.1, error: 101.459
# Epoch: 28, lrate: 0.1, error: 101.202
# Epoch: 29, lrate: 0.1, error: 100.96
# Epoch: 30, lrate: 0.1, error: 100.733
# Epoch: 31, lrate: 0.1, error: 100.519
# Epoch: 32, lrate: 0.1, error: 100.317
# Epoch: 33, lrate: 0.1, error: 100.126
# Epoch: 34, lrate: 0.1, error: 99.946
# Epoch: 35, lrate: 0.1, error: 99.775
# Epoch: 36, lrate: 0.1, error: 99.613
# Epoch: 37, lrate: 0.1, error: 99.459
# Epoch: 38, lrate: 0.1, error: 99.314
# Epoch: 39, lrate: 0.1, error: 99.175
# Epoch: 40, lrate: 0.1, error: 99.043
# Epoch: 41, lrate: 0.1, error: 98.917
# Epoch: 42, lrate: 0.1, error: 98.798
# Epoch: 43, lrate: 0.1, error: 98.683
# Epoch: 44, lrate: 0.1, error: 98.574
# Epoch: 45, lrate: 0.1, error: 98.47
# Epoch: 46, lrate: 0.1, error: 98.37
# Epoch: 47, lrate: 0.1, error: 98.275
# Epoch: 48, lrate: 0.1, error: 98.184
# Epoch: 49, lrate: 0.1, error: 98.096
# Epoch: 50, lrate: 0.1, error: 98.013
# Epoch: 51, lrate: 0.1, error: 97.932
# Epoch: 52, lrate: 0.1, error: 97.855
# Epoch: 53, lrate: 0.1, error: 97.781
# Epoch: 54, lrate: 0.1, error: 97.71
# Epoch: 55, lrate: 0.1, error: 97.642
# Epoch: 56, lrate: 0.1, error: 97.576
# Epoch: 57, lrate: 0.1, error: 97.513
# Epoch: 58, lrate: 0.1, error: 97.452
# Epoch: 59, lrate: 0.1, error: 97.394
# Epoch: 60, lrate: 0.1, error: 97.337
# Epoch: 61, lrate: 0.1, error: 97.283
# Epoch: 62, lrate: 0.1, error: 97.23
# Epoch: 63, lrate: 0.1, error: 97.18
# Epoch: 64, lrate: 0.1, error: 97.131
# Epoch: 65, lrate: 0.1, error: 97.084
# Epoch: 66, lrate: 0.1, error: 97.039
# Epoch: 67, lrate: 0.1, error: 96.995
# Epoch: 68, lrate: 0.1, error: 96.953
# Epoch: 69, lrate: 0.1, error: 96.912
# Epoch: 70, lrate: 0.1, error: 96.872
# Epoch: 71, lrate: 0.1, error: 96.834
# Epoch: 72, lrate: 0.1, error: 96.797
# Epoch: 73, lrate: 0.1, error: 96.761
# Epoch: 74, lrate: 0.1, error: 96.727
# Epoch: 75, lrate: 0.1, error: 96.693
# Epoch: 76, lrate: 0.1, error: 96.661
# Epoch: 77, lrate: 0.1, error: 96.629
# Epoch: 78, lrate: 0.1, error: 96.599
# Epoch: 79, lrate: 0.1, error: 96.57
# Epoch: 80, lrate: 0.1, error: 96.541
# Epoch: 81, lrate: 0.1, error: 96.513
# Epoch: 82, lrate: 0.1, error: 96.486
# Epoch: 83, lrate: 0.1, error: 96.46
# Epoch: 84, lrate: 0.1, error: 96.435
# Epoch: 85, lrate: 0.1, error: 96.411
# Epoch: 86, lrate: 0.1, error: 96.387
# Epoch: 87, lrate: 0.1, error: 96.364
# Epoch: 88, lrate: 0.1, error: 96.341
# Epoch: 89, lrate: 0.1, error: 96.32
# Epoch: 90, lrate: 0.1, error: 96.298
# Epoch: 91, lrate: 0.1, error: 96.278
# Epoch: 92, lrate: 0.1, error: 96.258
# Epoch: 93, lrate: 0.1, error: 96.239
# Epoch: 94, lrate: 0.1, error: 96.22
# Epoch: 95, lrate: 0.1, error: 96.201
# Epoch: 96, lrate: 0.1, error: 96.184
# Epoch: 97, lrate: 0.1, error: 96.166
# Epoch: 98, lrate: 0.1, error: 96.149
# Epoch: 99, lrate: 0.1, error: 96.133
# Epoch: 0, lrate: 0.1, error: 140.723
# Epoch: 1, lrate: 0.1, error: 133.858
# Epoch: 2, lrate: 0.1, error: 128.943
# Epoch: 3, lrate: 0.1, error: 124.999
# Epoch: 4, lrate: 0.1, error: 121.794
# Epoch: 5, lrate: 0.1, error: 119.146
# Epoch: 6, lrate: 0.1, error: 116.921
# Epoch: 7, lrate: 0.1, error: 115.023
# Epoch: 8, lrate: 0.1, error: 113.382
# Epoch: 9, lrate: 0.1, error: 111.948
# Epoch: 10, lrate: 0.1, error: 110.682
# Epoch: 11, lrate: 0.1, error: 109.556
# Epoch: 12, lrate: 0.1, error: 108.548
# Epoch: 13, lrate: 0.1, error: 107.641
# Epoch: 14, lrate: 0.1, error: 106.819
# Epoch: 15, lrate: 0.1, error: 106.072
# Epoch: 16, lrate: 0.1, error: 105.391
# Epoch: 17, lrate: 0.1, error: 104.766
# Epoch: 18, lrate: 0.1, error: 104.192
# Epoch: 19, lrate: 0.1, error: 103.663
# Epoch: 20, lrate: 0.1, error: 103.174
# Epoch: 21, lrate: 0.1, error: 102.721
# Epoch: 22, lrate: 0.1, error: 102.3
# Epoch: 23, lrate: 0.1, error: 101.907
# Epoch: 24, lrate: 0.1, error: 101.542
# Epoch: 25, lrate: 0.1, error: 101.2
# Epoch: 26, lrate: 0.1, error: 100.879
# Epoch: 27, lrate: 0.1, error: 100.578
# Epoch: 28, lrate: 0.1, error: 100.296
# Epoch: 29, lrate: 0.1, error: 100.03
# Epoch: 30, lrate: 0.1, error: 99.779
# Epoch: 31, lrate: 0.1, error: 99.542
# Epoch: 32, lrate: 0.1, error: 99.319
# Epoch: 33, lrate: 0.1, error: 99.107
# Epoch: 34, lrate: 0.1, error: 98.906
# Epoch: 35, lrate: 0.1, error: 98.716
# Epoch: 36, lrate: 0.1, error: 98.535
# Epoch: 37, lrate: 0.1, error: 98.363
# Epoch: 38, lrate: 0.1, error: 98.199
# Epoch: 39, lrate: 0.1, error: 98.043
# Epoch: 40, lrate: 0.1, error: 97.895
# Epoch: 41, lrate: 0.1, error: 97.753
# Epoch: 42, lrate: 0.1, error: 97.617
# Epoch: 43, lrate: 0.1, error: 97.488
# Epoch: 44, lrate: 0.1, error: 97.364
# Epoch: 45, lrate: 0.1, error: 97.245
# Epoch: 46, lrate: 0.1, error: 97.132
# Epoch: 47, lrate: 0.1, error: 97.023
# Epoch: 48, lrate: 0.1, error: 96.919
# Epoch: 49, lrate: 0.1, error: 96.819
# Epoch: 50, lrate: 0.1, error: 96.723
# Epoch: 51, lrate: 0.1, error: 96.63
# Epoch: 52, lrate: 0.1, error: 96.541
# Epoch: 53, lrate: 0.1, error: 96.456
# Epoch: 54, lrate: 0.1, error: 96.374
# Epoch: 55, lrate: 0.1, error: 96.295
# Epoch: 56, lrate: 0.1, error: 96.218
# Epoch: 57, lrate: 0.1, error: 96.145
# Epoch: 58, lrate: 0.1, error: 96.074
# Epoch: 59, lrate: 0.1, error: 96.006
# Epoch: 60, lrate: 0.1, error: 95.94
# Epoch: 61, lrate: 0.1, error: 95.876
# Epoch: 62, lrate: 0.1, error: 95.815
# Epoch: 63, lrate: 0.1, error: 95.755
# Epoch: 64, lrate: 0.1, error: 95.698
# Epoch: 65, lrate: 0.1, error: 95.643
# Epoch: 66, lrate: 0.1, error: 95.589
# Epoch: 67, lrate: 0.1, error: 95.537
# Epoch: 68, lrate: 0.1, error: 95.487
# Epoch: 69, lrate: 0.1, error: 95.438
# Epoch: 70, lrate: 0.1, error: 95.391
# Epoch: 71, lrate: 0.1, error: 95.345
# Epoch: 72, lrate: 0.1, error: 95.301
# Epoch: 73, lrate: 0.1, error: 95.258
# Epoch: 74, lrate: 0.1, error: 95.217
# Epoch: 75, lrate: 0.1, error: 95.176
# Epoch: 76, lrate: 0.1, error: 95.137
# Epoch: 77, lrate: 0.1, error: 95.099
# Epoch: 78, lrate: 0.1, error: 95.063
# Epoch: 79, lrate: 0.1, error: 95.027
# Epoch: 80, lrate: 0.1, error: 94.992
# Epoch: 81, lrate: 0.1, error: 94.958
# Epoch: 82, lrate: 0.1, error: 94.925
# Epoch: 83, lrate: 0.1, error: 94.894
# Epoch: 84, lrate: 0.1, error: 94.863
# Epoch: 85, lrate: 0.1, error: 94.832
# Epoch: 86, lrate: 0.1, error: 94.803
# Epoch: 87, lrate: 0.1, error: 94.775
# Epoch: 88, lrate: 0.1, error: 94.747
# Epoch: 89, lrate: 0.1, error: 94.72
# Epoch: 90, lrate: 0.1, error: 94.694
# Epoch: 91, lrate: 0.1, error: 94.668
# Epoch: 92, lrate: 0.1, error: 94.643
# Epoch: 93, lrate: 0.1, error: 94.619
# Epoch: 94, lrate: 0.1, error: 94.595
# Epoch: 95, lrate: 0.1, error: 94.572
# Epoch: 96, lrate: 0.1, error: 94.55
# Epoch: 97, lrate: 0.1, error: 94.528
# Epoch: 98, lrate: 0.1, error: 94.507
# Epoch: 99, lrate: 0.1, error: 94.486
# Epoch: 0, lrate: 0.1, error: 142.57
# Epoch: 1, lrate: 0.1, error: 134.535
# Epoch: 2, lrate: 0.1, error: 128.794
# Epoch: 3, lrate: 0.1, error: 124.254
# Epoch: 4, lrate: 0.1, error: 120.62
# Epoch: 5, lrate: 0.1, error: 117.662
# Epoch: 6, lrate: 0.1, error: 115.213
# Epoch: 7, lrate: 0.1, error: 113.154
# Epoch: 8, lrate: 0.1, error: 111.4
# Epoch: 9, lrate: 0.1, error: 109.886
# Epoch: 10, lrate: 0.1, error: 108.566
# Epoch: 11, lrate: 0.1, error: 107.405
# Epoch: 12, lrate: 0.1, error: 106.376
# Epoch: 13, lrate: 0.1, error: 105.458
# Epoch: 14, lrate: 0.1, error: 104.633
# Epoch: 15, lrate: 0.1, error: 103.888
# Epoch: 16, lrate: 0.1, error: 103.212
# Epoch: 17, lrate: 0.1, error: 102.596
# Epoch: 18, lrate: 0.1, error: 102.033
# Epoch: 19, lrate: 0.1, error: 101.515
# Epoch: 20, lrate: 0.1, error: 101.039
# Epoch: 21, lrate: 0.1, error: 100.598
# Epoch: 22, lrate: 0.1, error: 100.19
# Epoch: 23, lrate: 0.1, error: 99.811
# Epoch: 24, lrate: 0.1, error: 99.458
# Epoch: 25, lrate: 0.1, error: 99.128
# Epoch: 26, lrate: 0.1, error: 98.82
# Epoch: 27, lrate: 0.1, error: 98.532
# Epoch: 28, lrate: 0.1, error: 98.261
# Epoch: 29, lrate: 0.1, error: 98.006
# Epoch: 30, lrate: 0.1, error: 97.767
# Epoch: 31, lrate: 0.1, error: 97.541
# Epoch: 32, lrate: 0.1, error: 97.328
# Epoch: 33, lrate: 0.1, error: 97.126
# Epoch: 34, lrate: 0.1, error: 96.936
# Epoch: 35, lrate: 0.1, error: 96.755
# Epoch: 36, lrate: 0.1, error: 96.584
# Epoch: 37, lrate: 0.1, error: 96.422
# Epoch: 38, lrate: 0.1, error: 96.267
# Epoch: 39, lrate: 0.1, error: 96.12
# Epoch: 40, lrate: 0.1, error: 95.98
# Epoch: 41, lrate: 0.1, error: 95.847
# Epoch: 42, lrate: 0.1, error: 95.72
# Epoch: 43, lrate: 0.1, error: 95.599
# Epoch: 44, lrate: 0.1, error: 95.484
# Epoch: 45, lrate: 0.1, error: 95.373
# Epoch: 46, lrate: 0.1, error: 95.267
# Epoch: 47, lrate: 0.1, error: 95.166
# Epoch: 48, lrate: 0.1, error: 95.07
# Epoch: 49, lrate: 0.1, error: 94.977
# Epoch: 50, lrate: 0.1, error: 94.888
# Epoch: 51, lrate: 0.1, error: 94.803
# Epoch: 52, lrate: 0.1, error: 94.722
# Epoch: 53, lrate: 0.1, error: 94.643
# Epoch: 54, lrate: 0.1, error: 94.568
# Epoch: 55, lrate: 0.1, error: 94.496
# Epoch: 56, lrate: 0.1, error: 94.426
# Epoch: 57, lrate: 0.1, error: 94.36
# Epoch: 58, lrate: 0.1, error: 94.295
# Epoch: 59, lrate: 0.1, error: 94.233
# Epoch: 60, lrate: 0.1, error: 94.174
# Epoch: 61, lrate: 0.1, error: 94.117
# Epoch: 62, lrate: 0.1, error: 94.061
# Epoch: 63, lrate: 0.1, error: 94.008
# Epoch: 64, lrate: 0.1, error: 93.957
# Epoch: 65, lrate: 0.1, error: 93.907
# Epoch: 66, lrate: 0.1, error: 93.859
# Epoch: 67, lrate: 0.1, error: 93.813
# Epoch: 68, lrate: 0.1, error: 93.769
# Epoch: 69, lrate: 0.1, error: 93.726
# Epoch: 70, lrate: 0.1, error: 93.684
# Epoch: 71, lrate: 0.1, error: 93.644
# Epoch: 72, lrate: 0.1, error: 93.605
# Epoch: 73, lrate: 0.1, error: 93.568
# Epoch: 74, lrate: 0.1, error: 93.531
# Epoch: 75, lrate: 0.1, error: 93.496
# Epoch: 76, lrate: 0.1, error: 93.462
# Epoch: 77, lrate: 0.1, error: 93.429
# Epoch: 78, lrate: 0.1, error: 93.398
# Epoch: 79, lrate: 0.1, error: 93.367
# Epoch: 80, lrate: 0.1, error: 93.337
# Epoch: 81, lrate: 0.1, error: 93.308
# Epoch: 82, lrate: 0.1, error: 93.28
# Epoch: 83, lrate: 0.1, error: 93.253
# Epoch: 84, lrate: 0.1, error: 93.226
# Epoch: 85, lrate: 0.1, error: 93.201
# Epoch: 86, lrate: 0.1, error: 93.176
# Epoch: 87, lrate: 0.1, error: 93.152
# Epoch: 88, lrate: 0.1, error: 93.128
# Epoch: 89, lrate: 0.1, error: 93.106
# Epoch: 90, lrate: 0.1, error: 93.084
# Epoch: 91, lrate: 0.1, error: 93.062
# Epoch: 92, lrate: 0.1, error: 93.042
# Epoch: 93, lrate: 0.1, error: 93.022
# Epoch: 94, lrate: 0.1, error: 93.002
# Epoch: 95, lrate: 0.1, error: 92.983
# Epoch: 96, lrate: 0.1, error: 92.964
# Epoch: 97, lrate: 0.1, error: 92.946
# Epoch: 98, lrate: 0.1, error: 92.929
# Epoch: 99, lrate: 0.1, error: 92.912
# ScoresL [0.5113099925649136, 0.464420364012824, 0.4277926319464986, 0.4917622040778217, 0.4917622040778217]
# Mean Accuracy: 0.477409%
